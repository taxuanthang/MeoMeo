# %%
from main import *

# %%
img = cv2.imread("./datasets/sample1.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
scale = 1
img_in, img_out = pre_process_image(img, scale)
img_out_2 = np.copy(img_out)
img_out, bounding_boxes = detect_main(img_in, img_out, None, scale, False, False)
img_out = cv2.cvtColor(img_out, cv2.COLOR_BGR2RGB)
plt.imshow(img_out)
plt.show()

# %%
img = cv2.imread("./datasets/sample2.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
scale = 0.5
img_in, img_out = pre_process_image(img, scale)
img_out_2 = np.copy(img_out)
img_out, bounding_boxes = detect_main(img_in, img_out, None, scale, False, False)
img_out = cv2.cvtColor(img_out, cv2.COLOR_BGR2RGB)
plt.imshow(img_out)
plt.show()

# %%
img_out_2 = recognize_main(img_in, img_out_2, None, scale, False, False, bounding_boxes)
# Out:
# G:\ky1nam3\LIP\Anime-Face-Detection-and-Recognition\venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# G:\ky1nam3\LIP\Anime-Face-Detection-and-Recognition\venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 img_out_2 = recognize_main(img_in, img_out_2, None, scale, False, False, bounding_boxes)
#
# ...

# %%
img_out_2 = cv2.cvtColor(img_out_2, cv2.COLOR_BGR2RGB)
plt.imshow(img_out_2)
